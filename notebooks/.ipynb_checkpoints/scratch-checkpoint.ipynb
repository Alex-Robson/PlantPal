# %%
import pandas as pd
plants_df = pd.read_csv('../data/House_Plants.csv', skiprows=2,
                        names=['name','type','latin_name',
                               'name_1','name_2','name_3',
                               'water_lmh','water_desc',
                               'light', 'issues', 'fert',
                               'cat_tox', 'cat_tox_desc',
                               'dog_tox', 'dog_tox_desc',
                               'fun_fact'])

# %%
plants_df.name[0]
# Out:
# 'Aloe Vera'

# %%
plant_df = plants_df[plants_df['name'] == 'Aloe Vera']

# %%
plants_df[plants_df['name'] == 'Aloe Vera']
# Out:
#         name                type               latin_name name_1 name_2  \
# 0  Aloe Vera  Cactus / Succulent  Aloe barbadensis miller    NaN    NaN
#
#   name_3 water_lmh                       water_desc                light  \
# 0    NaN       Low  Water deeply once every 7 days.  Bright and indirect
#
#   issues  fert cat_tox                                       cat_tox_desc  \
# 0    NaN   NaN    Mild  Vomiting, diarrhoea, lethargy, depression, ano...
#
#   dog_tox                                       dog_tox_desc fun_fact
# 0   Mild   Vomiting, diarrhoea, lethargy, depression, ano...      NaN

# %%
import tensorflow as tf
temp = tf.keras.models.load_model('../models/convmod_1.0.h5')
dot_img_file = '../models/convmod_1.0.png'
tf.keras.utils.plot_model(temp, to_file=dot_img_file, show_shapes=True)

# %%
from PIL import Image
import glob

def crop_shutterstock(path):
    
    original = Image.open(path)
#     original.show()

    width, height = original.size   # Get dimensions
    left = 0
    top = 0
    right = width
    bottom = 7 * height/8
    cropped_example = original.crop((left, top, right, bottom))
#     cropped_example.show()
    cropped_example.save(path)

# %%
for directory in glob.glob('../data/shutterstock/*'):
    for file in glob.glob(f'{directory}/*'):
        crop_shutterstock(file)

# %%
for directory in glob.glob('../data/shutterstock/*'):
    for file in glob.glob(f'{directory}/*'):

# %%
'k'*10
# Out:
# 'kkkkkkkkkk'

# %%
for from PIL import Image
import glob

def reshape_image(path):
    
    original = Image.open(path)

# %%
import numpy as np

blah = np.zeros(5)

# %%
blah = [[1,2,3,4,5]]

# %%
np.shape(blah)
# Out:
# (1, 5)

# %%
blah[0][-2:]
# Out:
# [4, 5]

# %%
classes = ['a', 'b', 'c']
vals = [0.5, 0.2,0.8]
df

# %%
dic = dict({0: True, 1: False})

def find_key_true(input_dict):
    return next((k for k, v in input_dict.items() if v == True), None)

find_key_true(dic)
# Out:
# 0

# %%
import glob
import os

# %%
import glob
import os 

for folder in glob.glob('../data/rename_test/*'):
    print(folder)
    for i, file in enumerate(glob.glob(f'{folder}/*')):
        name = folder.split('/')[-1]
        extension = file.split('.')[-1]
        os.rename(file, f'{folder}/{name}_{i}.{extension}')
# Out:
# ../data/rename_test/Blah
# ../data/rename_test/Aloe_Vera
