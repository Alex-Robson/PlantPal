# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import pathlib
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications.densenet import DenseNet121, DenseNet169, DenseNet201

from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D, GlobalMaxPooling2D

print(tf.__version__)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %load_ext tensorboard
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-1b6ccaddd7bc> in <module>
#       5 import PIL
#       6 import pathlib
# ----> 7 from sklearn.utils import class_weight
#       8
#       9 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# # Data

# %% [markdown]
# ## Load data

# %% [markdown]
# **data is structured as:**
#
#        ../data/
#             multiclass_200/
#                     Aloe_Vera/
#                         Aloe_Vera_1.jpeg
#                         Aloe_Vera_2.jpeg
#                         ...
#                     ...
#                     Umbrella_Tree/
#                         Umbrella_Tree_1.jpeg
#                         Umbrella_Tree_2.jpeg
#                         ...
#             House_Plants.csv

# %% [markdown]
# **Define dataset location and desired size:**

# %%
data_path = '../data/gsp_17_jpeg_purged/'
batch_size = 32
img_height = 224
img_width = 224

# %% [markdown]
# ## Load data

# %%
# 80% training set
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

# 20% validation set
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 13074 files belonging to 15 classes.
# Using 10460 files for training.
# Found 13074 files belonging to 15 classes.
# Using 2614 files for validation.

# %% [markdown]
# **List classes**

# %%
class_names = train_ds.class_names
no_classes = len(class_names)
print(class_names)
# Out:
# ['Aloe_Vera', 'Asparagus_Fern', 'Baby_Rubber_Plant', 'Boston_Fern', 'Easter_Lily', 'Fiddle_Leaf_Fig', 'Jade_Plant', 'Monstera', 'Parlor_Palm', 'Peace_Lily', 'Pothos', 'Rubber_Plant', 'Snake_Plant', 'Spider_Plant', 'Umbrella_Tree']

# %%
train_ds.

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 224, 224, 3)
# (32,)

# %% [markdown]
# Note: Using class_weights changes the range of the loss. This may affect the stability of the training depending on the optimizer. Optimizers whose step size is dependent on the magnitude of the gradient, like optimizers.SGD, may fail. The optimizer used here, optimizers.Adam, is unaffected by the scaling change. Also note that because of the weighting, the total losses are not comparable between the two models.

# %%
label_list = []
for images, labels in train_ds.take(-1):
    batch_labels = labels.numpy()
    label_list.append(batch_labels)
    
label_list = np.concatenate( label_list, axis=0 )

# %%
class_weight_arr = class_weight.compute_class_weight('balanced',
                                                 np.unique(label_list),
                                                 label_list)

class_weight_dict = dict(zip(np.arange(no_classes), class_weight_arr)) #.astype(str)

# %% [markdown]
# ## Visualize raw data

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ## Preprocess the data

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.3),
  ]
)

# %% [markdown]
# **Visualize**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ## Prefetch the data

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Build model

# %% [markdown]
# **First try**

# %%
def get_prelim():
    model = Sequential([
        layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical", 
                                                     input_shape=(img_height, img_width, 3)),
        layers.experimental.preprocessing.RandomRotation(0.2),
        layers.experimental.preprocessing.RandomZoom(0.3),
        layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
        layers.Conv2D(16, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(no_classes),
        layers.Activation('softmax')
    ])
    return model

def get_double_conv_1():
    model = keras.models.Sequential([
        layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical", 
                                                     input_shape=(img_height, img_width, 3)),
        layers.experimental.preprocessing.RandomRotation(0.2),
        layers.experimental.preprocessing.RandomZoom(0.3),
        layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
        layers.Conv2D(64, 7, activation='relu', padding='same'),
        layers.MaxPooling2D(2),
        layers.Conv2D(128, 3, activation='relu', padding='same'),
        layers.Conv2D(128, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(2),
        layers.Conv2D(256, 3, activation='relu', padding='same'),
        layers.Conv2D(256, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(no_classes, activation='softmax')
    ])
    return model

def get_dropout_1():
    model = Sequential([
        layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical", 
                                                     input_shape=(img_height, img_width, 3)),
        layers.experimental.preprocessing.RandomRotation(0.2),
        layers.experimental.preprocessing.RandomZoom(0.3),
        layers.experimental.preprocessing.Rescaling(1./255),
        layers.Conv2D(16, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(no_classes, activation='softmax')
    ])
    return model

def get_VGG16tl():
    resize_layer = layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))

    # create the base model from the pre-trained model VGG16
    # note that, if using a Kaggle server, internet has to be turned on
    pretrained_model = VGG16(input_shape=(img_height, img_width, 3),
                                                         include_top=False,
                                                         weights='imagenet')

    # freeze the convolutional base
    pretrained_model.trainable = False

    model = tf.keras.Sequential([
#         layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical", 
#                                                      input_shape=(img_height, img_width, 3)),
#         layers.experimental.preprocessing.RandomRotation(0.2),
#         layers.experimental.preprocessing.RandomZoom(0.3),
        resize_layer,
        pretrained_model,
        # GlobalAveragePooling2D(), # maybe make max (first) or not at all
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5), # try 0.5
        Dense(256, activation='relu'),
        Dense(no_classes, activation='softmax')])
    return model

def get_InceptionV3tl():
    resize_layer = layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))

    # create the base model from the pre-trained model VGG16
    # note that, if using a Kaggle server, internet has to be turned on
    pretrained_model = InceptionV3(input_shape=(img_height, img_width, 3),
                                                         include_top=False,
                                                         weights='imagenet')

    # freeze the convolutional base
    pretrained_model.trainable = False

    model = tf.keras.Sequential([resize_layer,
                                 pretrained_model,
#                                  GlobalMaxPooling2D(),
                                 Flatten(),
                                 Dense(256, activation='relu'),
                                 Dropout(0.5),
                                 Dense(256, activation='relu'),
                                 Dense(no_classes, activation='softmax')])
    return model

def get_InceptionV3tl2():
    resize_layer = layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))

    # create the base model from the pre-trained model VGG16
    # note that, if using a Kaggle server, internet has to be turned on
    pretrained_model = InceptionV3(input_shape=(img_height, img_width, 3),
                                                         include_top=False,
                                                         weights='imagenet')

    # freeze the convolutional base
    pretrained_model.trainable = False

    model = tf.keras.Sequential([resize_layer,
                                 pretrained_model,
#                                  GlobalMaxPooling2D(),
                                 Flatten(),
                                 Dense(1024, activation='relu'),
                                 Dropout(0.2),
                                 Dense(no_classes, activation='softmax')])
    return model


def get_ResNet50tl():
    resize_layer = layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))

    # create the base model from the pre-trained model VGG16
    # note that, if using a Kaggle server, internet has to be turned on
    pretrained_model = ResNet50(input_shape=(img_height, img_width, 3),
                                                         include_top=False,
                                                         weights='imagenet')

    # freeze the convolutional base
    pretrained_model.trainable = False

    model = tf.keras.Sequential([resize_layer,
                                 pretrained_model,
#                                  GlobalAveragePooling2D(),
                                 Flatten(),
                                 Dense(256, activation='relu'),
                                 Dropout(0.5),
                                 Dense(256, activation='relu'),
                                 Dense(no_classes, activation='softmax')])
    return model

def get_InceptionResNetV2tl():
    resize_layer = layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))

    # create the base model from the pre-trained model VGG16
    # note that, if using a Kaggle server, internet has to be turned on
    pretrained_model = InceptionResNetV2(input_shape=(img_height, img_width, 3),
                                                         include_top=False,
                                                         weights='imagenet')

    # freeze the convolutional base
    pretrained_model.trainable = False

    model = tf.keras.Sequential([resize_layer,
                                 pretrained_model,
#                                  GlobalAveragePooling2D(),
                                 Flatten(),
                                 Dense(256, activation='relu'),
                                 Dropout(0.5),
                                 Dense(256, activation='relu'),
                                 Dense(no_classes, activation='softmax')])
    return model

def generate_model(model_name):
    
    if model_name == 'prelim':
        model = get_prelim()
        data_augmentation
    
    elif model_name == 'double_conv_1':
        model = get_double_conv_1()
    
    elif model_name == 'dropout_1':
        model = get_dropout_1()
    
    elif model_name == 'VGG16':
        model = get_VGG16tl()
    
    elif model_name == 'ResNet50':
        model = get_ResNet50tl()
    
    elif model_name == 'InceptionV3':
        model = get_InceptionV3tl()
    
    elif model_name == 'InceptionV3_1024':
        model = get_InceptionV3tl2()
  
    elif model_name == 'InceptionResNetV2':
        model = get_InceptionResNetV2tl()
    
    else:
        print('please select a valid model')
        
    
#     model = tf.keras.Sequential([
#         data_augmentation,
#         model
#     ])
    
    return model

# %%
# model = generate_model('VGG16')
# model = generate_model('ResNet50')
# model = generate_model('InceptionV3')
model = generate_model('InceptionV3_1024')
# model = generate_model('InceptionResNetV2')
# model = generate_model('double_conv_1')

# UPDATE PREPROCESSING IN DEFINITIONS!!!

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
            optimizer = 'adam',
            metrics = ['accuracy', 'sparse_top_k_categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                3855
# =================================================================
# Total params: 34,979,887
# Trainable params: 13,177,103
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %% [markdown]
# # Train model

# %%
initial_epochs=40

history = model.fit(train_ds,
                    epochs=initial_epochs,
                    validation_data=val_ds,
                    class_weight=class_weight_dict)
# Out:
# Epoch 1/40
# 327/327 [==============================] - 72s 221ms/step - loss: 3.1030 - accuracy: 0.1021 - sparse_top_k_categorical_accuracy: 0.4469 - val_loss: 2.1070 - val_accuracy: 0.2582 - val_sparse_top_k_categorical_accuracy: 0.7636
# Epoch 2/40
# 327/327 [==============================] - 67s 206ms/step - loss: 2.5895 - accuracy: 0.1011 - sparse_top_k_categorical_accuracy: 0.4402 - val_loss: 2.5458 - val_accuracy: 0.1098 - val_sparse_top_k_categorical_accuracy: 0.4013
# Epoch 3/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6114 - accuracy: 0.0681 - sparse_top_k_categorical_accuracy: 0.3391 - val_loss: 2.4709 - val_accuracy: 0.1262 - val_sparse_top_k_categorical_accuracy: 0.3906
# Epoch 4/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.7013 - accuracy: 0.0285 - sparse_top_k_categorical_accuracy: 0.3148 - val_loss: 2.6268 - val_accuracy: 0.0566 - val_sparse_top_k_categorical_accuracy: 0.4017
# Epoch 5/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6632 - accuracy: 0.1213 - sparse_top_k_categorical_accuracy: 0.4060 - val_loss: 2.5239 - val_accuracy: 0.0930 - val_sparse_top_k_categorical_accuracy: 0.3669
# Epoch 6/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6420 - accuracy: 0.0739 - sparse_top_k_categorical_accuracy: 0.3023 - val_loss: 2.4999 - val_accuracy: 0.1488 - val_sparse_top_k_categorical_accuracy: 0.2437
# Epoch 7/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6446 - accuracy: 0.1131 - sparse_top_k_categorical_accuracy: 0.2789 - val_loss: 2.4740 - val_accuracy: 0.2510 - val_sparse_top_k_categorical_accuracy: 0.4147
# Epoch 8/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6464 - accuracy: 0.1112 - sparse_top_k_categorical_accuracy: 0.3311 - val_loss: 2.5550 - val_accuracy: 0.1018 - val_sparse_top_k_categorical_accuracy: 0.3416
# Epoch 9/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6448 - accuracy: 0.0910 - sparse_top_k_categorical_accuracy: 0.3377 - val_loss: 2.5243 - val_accuracy: 0.1041 - val_sparse_top_k_categorical_accuracy: 0.2418
# Epoch 10/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6668 - accuracy: 0.0719 - sparse_top_k_categorical_accuracy: 0.2752 - val_loss: 2.3573 - val_accuracy: 0.1534 - val_sparse_top_k_categorical_accuracy: 0.5164
# Epoch 11/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6394 - accuracy: 0.0875 - sparse_top_k_categorical_accuracy: 0.3420 - val_loss: 2.4814 - val_accuracy: 0.1075 - val_sparse_top_k_categorical_accuracy: 0.4376
# Epoch 12/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6300 - accuracy: 0.1252 - sparse_top_k_categorical_accuracy: 0.3935 - val_loss: 2.5831 - val_accuracy: 0.1159 - val_sparse_top_k_categorical_accuracy: 0.3734
# Epoch 13/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6307 - accuracy: 0.0847 - sparse_top_k_categorical_accuracy: 0.3479 - val_loss: 2.4195 - val_accuracy: 0.1419 - val_sparse_top_k_categorical_accuracy: 0.5115
# Epoch 14/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6211 - accuracy: 0.1075 - sparse_top_k_categorical_accuracy: 0.3868 - val_loss: 2.3457 - val_accuracy: 0.1691 - val_sparse_top_k_categorical_accuracy: 0.5788
# Epoch 15/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.6070 - accuracy: 0.1342 - sparse_top_k_categorical_accuracy: 0.4043 - val_loss: 2.3792 - val_accuracy: 0.1725 - val_sparse_top_k_categorical_accuracy: 0.4327
# Epoch 16/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5843 - accuracy: 0.1066 - sparse_top_k_categorical_accuracy: 0.4377 - val_loss: 2.4067 - val_accuracy: 0.1205 - val_sparse_top_k_categorical_accuracy: 0.6067
# Epoch 17/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5807 - accuracy: 0.1000 - sparse_top_k_categorical_accuracy: 0.3942 - val_loss: 2.3359 - val_accuracy: 0.0876 - val_sparse_top_k_categorical_accuracy: 0.6752
# Epoch 18/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5526 - accuracy: 0.1010 - sparse_top_k_categorical_accuracy: 0.4262 - val_loss: 2.2807 - val_accuracy: 0.1297 - val_sparse_top_k_categorical_accuracy: 0.7368
# Epoch 19/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5319 - accuracy: 0.1047 - sparse_top_k_categorical_accuracy: 0.4873 - val_loss: 2.3822 - val_accuracy: 0.1756 - val_sparse_top_k_categorical_accuracy: 0.5631
# Epoch 20/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5294 - accuracy: 0.1078 - sparse_top_k_categorical_accuracy: 0.4392 - val_loss: 2.2767 - val_accuracy: 0.1431 - val_sparse_top_k_categorical_accuracy: 0.5933
# Epoch 21/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5142 - accuracy: 0.1035 - sparse_top_k_categorical_accuracy: 0.4570 - val_loss: 2.4520 - val_accuracy: 0.1014 - val_sparse_top_k_categorical_accuracy: 0.4633
# Epoch 22/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5261 - accuracy: 0.1052 - sparse_top_k_categorical_accuracy: 0.4215 - val_loss: 2.3087 - val_accuracy: 0.2682 - val_sparse_top_k_categorical_accuracy: 0.7238
# Epoch 23/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5140 - accuracy: 0.1060 - sparse_top_k_categorical_accuracy: 0.4338 - val_loss: 2.2653 - val_accuracy: 0.1886 - val_sparse_top_k_categorical_accuracy: 0.7066
# Epoch 24/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5336 - accuracy: 0.0988 - sparse_top_k_categorical_accuracy: 0.4166 - val_loss: 2.3288 - val_accuracy: 0.1033 - val_sparse_top_k_categorical_accuracy: 0.6018
# Epoch 25/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.5266 - accuracy: 0.1067 - sparse_top_k_categorical_accuracy: 0.4106 - val_loss: 2.3355 - val_accuracy: 0.0991 - val_sparse_top_k_categorical_accuracy: 0.5444
# Epoch 26/40
# 327/327 [==============================] - 69s 210ms/step - loss: 2.4979 - accuracy: 0.1106 - sparse_top_k_categorical_accuracy: 0.4336 - val_loss: 2.3232 - val_accuracy: 0.1515 - val_sparse_top_k_categorical_accuracy: 0.5769
# Epoch 27/40
# 327/327 [==============================] - 69s 211ms/step - loss: 2.5010 - accuracy: 0.1010 - sparse_top_k_categorical_accuracy: 0.4373 - val_loss: 2.3116 - val_accuracy: 0.1714 - val_sparse_top_k_categorical_accuracy: 0.5761
# Epoch 28/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4804 - accuracy: 0.1185 - sparse_top_k_categorical_accuracy: 0.4220 - val_loss: 2.3176 - val_accuracy: 0.1419 - val_sparse_top_k_categorical_accuracy: 0.5853
# Epoch 29/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4861 - accuracy: 0.1318 - sparse_top_k_categorical_accuracy: 0.4722 - val_loss: 2.3322 - val_accuracy: 0.1503 - val_sparse_top_k_categorical_accuracy: 0.5937
# Epoch 30/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4793 - accuracy: 0.1173 - sparse_top_k_categorical_accuracy: 0.4363 - val_loss: 2.3379 - val_accuracy: 0.1064 - val_sparse_top_k_categorical_accuracy: 0.6599
# Epoch 31/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4874 - accuracy: 0.1144 - sparse_top_k_categorical_accuracy: 0.4490 - val_loss: 2.3041 - val_accuracy: 0.1320 - val_sparse_top_k_categorical_accuracy: 0.6836
# Epoch 32/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4693 - accuracy: 0.1187 - sparse_top_k_categorical_accuracy: 0.4649 - val_loss: 2.4474 - val_accuracy: 0.0888 - val_sparse_top_k_categorical_accuracy: 0.5658
# Epoch 33/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4682 - accuracy: 0.1084 - sparse_top_k_categorical_accuracy: 0.4581 - val_loss: 2.3540 - val_accuracy: 0.1293 - val_sparse_top_k_categorical_accuracy: 0.5451
# Epoch 34/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4919 - accuracy: 0.1046 - sparse_top_k_categorical_accuracy: 0.4357 - val_loss: 2.5134 - val_accuracy: 0.0983 - val_sparse_top_k_categorical_accuracy: 0.5065
# Epoch 35/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4796 - accuracy: 0.1248 - sparse_top_k_categorical_accuracy: 0.4385 - val_loss: 2.3962 - val_accuracy: 0.0838 - val_sparse_top_k_categorical_accuracy: 0.5746
# Epoch 36/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4716 - accuracy: 0.1081 - sparse_top_k_categorical_accuracy: 0.4098 - val_loss: 2.3427 - val_accuracy: 0.1714 - val_sparse_top_k_categorical_accuracy: 0.5834
# Epoch 37/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4600 - accuracy: 0.1465 - sparse_top_k_categorical_accuracy: 0.4437 - val_loss: 2.4120 - val_accuracy: 0.1262 - val_sparse_top_k_categorical_accuracy: 0.5295
# Epoch 38/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4509 - accuracy: 0.1291 - sparse_top_k_categorical_accuracy: 0.4773 - val_loss: 2.3472 - val_accuracy: 0.1182 - val_sparse_top_k_categorical_accuracy: 0.6006
# Epoch 39/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4600 - accuracy: 0.1151 - sparse_top_k_categorical_accuracy: 0.4413 - val_loss: 2.5187 - val_accuracy: 0.0995 - val_sparse_top_k_categorical_accuracy: 0.5061
# Epoch 40/40
# 327/327 [==============================] - 68s 208ms/step - loss: 2.4582 - accuracy: 0.1078 - sparse_top_k_categorical_accuracy: 0.4438 - val_loss: 2.5118 - val_accuracy: 0.1018 - val_sparse_top_k_categorical_accuracy: 0.6106

# %%
# unfreeze the layers
model.trainable = True

# %%
# let's take a look to see how many layers are in the base model
# print("Number of layers in the model: ", len(model.layers))

# # fine-tune from this layer onwards
# fine_tune_at = 15

# # freeze all the layers before the `fine_tune_at` layer
# for layer in pretrained_model.layers[:fine_tune_at]:
#        layer.trainable =  False


model.compile(loss = 'sparse_categorical_crossentropy',
            optimizer = keras.optimizers.Adam(1e-5),
            metrics = ['accuracy', 'sparse_top_k_categorical_accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                3855
# =================================================================
# Total params: 34,979,887
# Trainable params: 34,945,455
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
fine_tune_epochs = 200
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_ds,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1]+1,
                         validation_data=val_ds,
                         class_weight=class_weight_dict)
# Out:
# Epoch 41/240
#   2/327 [..............................] - ETA: 1:33 - loss: 2.6309 - accuracy: 0.0781 - sparse_top_k_categorical_accuracy: 0.4219WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2098s vs `on_train_batch_end` time: 0.3656s). Check your callbacks.
# 327/327 [==============================] - 201s 616ms/step - loss: 2.6235 - accuracy: 0.0641 - sparse_top_k_categorical_accuracy: 0.4079 - val_loss: 2.5877 - val_accuracy: 0.1155 - val_sparse_top_k_categorical_accuracy: 0.5769
# Epoch 42/240
# 327/327 [==============================] - 198s 605ms/step - loss: 2.5589 - accuracy: 0.0798 - sparse_top_k_categorical_accuracy: 0.3963 - val_loss: 2.4934 - val_accuracy: 0.1174 - val_sparse_top_k_categorical_accuracy: 0.5249
# Epoch 43/240
# 327/327 [==============================] - 198s 605ms/step - loss: 2.5113 - accuracy: 0.1000 - sparse_top_k_categorical_accuracy: 0.4035 - val_loss: 2.4797 - val_accuracy: 0.1197 - val_sparse_top_k_categorical_accuracy: 0.5252
# Epoch 44/240
# 327/327 [==============================] - 198s 605ms/step - loss: 2.4930 - accuracy: 0.1121 - sparse_top_k_categorical_accuracy: 0.4141 - val_loss: 2.4201 - val_accuracy: 0.1316 - val_sparse_top_k_categorical_accuracy: 0.5497
# Epoch 45/240
# 327/327 [==============================] - 198s 605ms/step - loss: 2.4741 - accuracy: 0.1138 - sparse_top_k_categorical_accuracy: 0.4139 - val_loss: 2.3723 - val_accuracy: 0.1438 - val_sparse_top_k_categorical_accuracy: 0.5677
# Epoch 46/240
# 327/327 [==============================] - 198s 605ms/step - loss: 2.4591 - accuracy: 0.1248 - sparse_top_k_categorical_accuracy: 0.4368 - val_loss: 2.3649 - val_accuracy: 0.1469 - val_sparse_top_k_categorical_accuracy: 0.5723
# Epoch 47/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.4337 - accuracy: 0.1224 - sparse_top_k_categorical_accuracy: 0.4411 - val_loss: 2.3287 - val_accuracy: 0.1507 - val_sparse_top_k_categorical_accuracy: 0.5995
# Epoch 48/240
# 327/327 [==============================] - 197s 603ms/step - loss: 2.4394 - accuracy: 0.1316 - sparse_top_k_categorical_accuracy: 0.4492 - val_loss: 2.3112 - val_accuracy: 0.1557 - val_sparse_top_k_categorical_accuracy: 0.6117
# Epoch 49/240
# 327/327 [==============================] - 197s 603ms/step - loss: 2.4284 - accuracy: 0.1343 - sparse_top_k_categorical_accuracy: 0.4486 - val_loss: 2.3000 - val_accuracy: 0.1523 - val_sparse_top_k_categorical_accuracy: 0.6155
# Epoch 50/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.4305 - accuracy: 0.1323 - sparse_top_k_categorical_accuracy: 0.4408 - val_loss: 2.2020 - val_accuracy: 0.1683 - val_sparse_top_k_categorical_accuracy: 0.6645
# Epoch 51/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.4276 - accuracy: 0.1354 - sparse_top_k_categorical_accuracy: 0.4450 - val_loss: 2.2702 - val_accuracy: 0.1584 - val_sparse_top_k_categorical_accuracy: 0.6331
# Epoch 52/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.4194 - accuracy: 0.1430 - sparse_top_k_categorical_accuracy: 0.4512 - val_loss: 2.2512 - val_accuracy: 0.1561 - val_sparse_top_k_categorical_accuracy: 0.6423
# Epoch 53/240
# 327/327 [==============================] - 197s 603ms/step - loss: 2.4028 - accuracy: 0.1505 - sparse_top_k_categorical_accuracy: 0.4614 - val_loss: 2.2501 - val_accuracy: 0.1599 - val_sparse_top_k_categorical_accuracy: 0.6370
# Epoch 54/240
# 327/327 [==============================] - 198s 605ms/step - loss: 2.3852 - accuracy: 0.1544 - sparse_top_k_categorical_accuracy: 0.4635 - val_loss: 2.2503 - val_accuracy: 0.1607 - val_sparse_top_k_categorical_accuracy: 0.6377
# Epoch 55/240
# 327/327 [==============================] - 197s 604ms/step - loss: 2.3870 - accuracy: 0.1663 - sparse_top_k_categorical_accuracy: 0.4585 - val_loss: 2.1982 - val_accuracy: 0.1733 - val_sparse_top_k_categorical_accuracy: 0.6614
# Epoch 56/240
# 327/327 [==============================] - 197s 604ms/step - loss: 2.3814 - accuracy: 0.1752 - sparse_top_k_categorical_accuracy: 0.4580 - val_loss: 2.1117 - val_accuracy: 0.1886 - val_sparse_top_k_categorical_accuracy: 0.6966
# Epoch 57/240
# 327/327 [==============================] - 195s 598ms/step - loss: 2.3847 - accuracy: 0.1696 - sparse_top_k_categorical_accuracy: 0.4563 - val_loss: 2.2406 - val_accuracy: 0.1500 - val_sparse_top_k_categorical_accuracy: 0.6442
# Epoch 58/240
# 327/327 [==============================] - 198s 607ms/step - loss: 2.4131 - accuracy: 0.1583 - sparse_top_k_categorical_accuracy: 0.4501 - val_loss: 2.2964 - val_accuracy: 0.1408 - val_sparse_top_k_categorical_accuracy: 0.6182
# Epoch 59/240
# 327/327 [==============================] - 194s 594ms/step - loss: 2.3907 - accuracy: 0.1583 - sparse_top_k_categorical_accuracy: 0.4562 - val_loss: 2.1587 - val_accuracy: 0.1794 - val_sparse_top_k_categorical_accuracy: 0.6855
# Epoch 60/240
# 327/327 [==============================] - 196s 600ms/step - loss: 2.3817 - accuracy: 0.1644 - sparse_top_k_categorical_accuracy: 0.4621 - val_loss: 2.1799 - val_accuracy: 0.1764 - val_sparse_top_k_categorical_accuracy: 0.6764
# Epoch 61/240
# 327/327 [==============================] - 197s 604ms/step - loss: 2.3834 - accuracy: 0.1729 - sparse_top_k_categorical_accuracy: 0.4678 - val_loss: 2.1466 - val_accuracy: 0.1825 - val_sparse_top_k_categorical_accuracy: 0.6878
# Epoch 62/240
# 327/327 [==============================] - 197s 604ms/step - loss: 2.3793 - accuracy: 0.1744 - sparse_top_k_categorical_accuracy: 0.4586 - val_loss: 2.1531 - val_accuracy: 0.1840 - val_sparse_top_k_categorical_accuracy: 0.6886
# Epoch 63/240
# 327/327 [==============================] - 197s 603ms/step - loss: 2.3686 - accuracy: 0.1870 - sparse_top_k_categorical_accuracy: 0.4671 - val_loss: 2.1430 - val_accuracy: 0.1886 - val_sparse_top_k_categorical_accuracy: 0.6894
# Epoch 64/240
# 327/327 [==============================] - 197s 604ms/step - loss: 2.3717 - accuracy: 0.1914 - sparse_top_k_categorical_accuracy: 0.4659 - val_loss: 2.1193 - val_accuracy: 0.1909 - val_sparse_top_k_categorical_accuracy: 0.7073
# Epoch 65/240
# 327/327 [==============================] - 197s 604ms/step - loss: 2.3635 - accuracy: 0.1975 - sparse_top_k_categorical_accuracy: 0.4682 - val_loss: 2.1050 - val_accuracy: 0.2008 - val_sparse_top_k_categorical_accuracy: 0.7050
# Epoch 66/240
# 327/327 [==============================] - 197s 604ms/step - loss: 2.3434 - accuracy: 0.2033 - sparse_top_k_categorical_accuracy: 0.4709 - val_loss: 2.1729 - val_accuracy: 0.1737 - val_sparse_top_k_categorical_accuracy: 0.6878
# Epoch 67/240
# 327/327 [==============================] - 197s 603ms/step - loss: 2.3571 - accuracy: 0.1912 - sparse_top_k_categorical_accuracy: 0.4657 - val_loss: 2.0989 - val_accuracy: 0.1940 - val_sparse_top_k_categorical_accuracy: 0.7043
# Epoch 68/240
# 327/327 [==============================] - 196s 598ms/step - loss: 2.3534 - accuracy: 0.1971 - sparse_top_k_categorical_accuracy: 0.4623 - val_loss: 2.1166 - val_accuracy: 0.1871 - val_sparse_top_k_categorical_accuracy: 0.7085
# Epoch 69/240
# 327/327 [==============================] - 198s 606ms/step - loss: 2.3617 - accuracy: 0.1966 - sparse_top_k_categorical_accuracy: 0.4680 - val_loss: 2.2142 - val_accuracy: 0.1584 - val_sparse_top_k_categorical_accuracy: 0.6672
# Epoch 70/240
# 327/327 [==============================] - 195s 596ms/step - loss: 2.3812 - accuracy: 0.1880 - sparse_top_k_categorical_accuracy: 0.4673 - val_loss: 2.0863 - val_accuracy: 0.2020 - val_sparse_top_k_categorical_accuracy: 0.7188
# Epoch 71/240
# 327/327 [==============================] - 196s 600ms/step - loss: 2.3431 - accuracy: 0.1999 - sparse_top_k_categorical_accuracy: 0.4725 - val_loss: 2.0896 - val_accuracy: 0.1966 - val_sparse_top_k_categorical_accuracy: 0.7204
# Epoch 72/240
# 327/327 [==============================] - 196s 600ms/step - loss: 2.3467 - accuracy: 0.2120 - sparse_top_k_categorical_accuracy: 0.4693 - val_loss: 2.0954 - val_accuracy: 0.1959 - val_sparse_top_k_categorical_accuracy: 0.7177
# Epoch 73/240
# 327/327 [==============================] - 198s 607ms/step - loss: 2.3438 - accuracy: 0.2128 - sparse_top_k_categorical_accuracy: 0.4707 - val_loss: 2.0583 - val_accuracy: 0.2119 - val_sparse_top_k_categorical_accuracy: 0.7341
# Epoch 74/240
# 327/327 [==============================] - 195s 596ms/step - loss: 2.3455 - accuracy: 0.2161 - sparse_top_k_categorical_accuracy: 0.4725 - val_loss: 2.0605 - val_accuracy: 0.2062 - val_sparse_top_k_categorical_accuracy: 0.7276
# Epoch 75/240
# 327/327 [==============================] - 196s 599ms/step - loss: 2.3364 - accuracy: 0.2199 - sparse_top_k_categorical_accuracy: 0.4710 - val_loss: 2.1364 - val_accuracy: 0.1737 - val_sparse_top_k_categorical_accuracy: 0.6997
# Epoch 76/240
# 327/327 [==============================] - 196s 600ms/step - loss: 2.3410 - accuracy: 0.2130 - sparse_top_k_categorical_accuracy: 0.4725 - val_loss: 2.0637 - val_accuracy: 0.2016 - val_sparse_top_k_categorical_accuracy: 0.7349
# Epoch 77/240
# 327/327 [==============================] - 197s 603ms/step - loss: 2.3276 - accuracy: 0.2368 - sparse_top_k_categorical_accuracy: 0.4772 - val_loss: 2.0278 - val_accuracy: 0.2215 - val_sparse_top_k_categorical_accuracy: 0.7399
# Epoch 78/240
# 327/327 [==============================] - 198s 605ms/step - loss: 2.3265 - accuracy: 0.2312 - sparse_top_k_categorical_accuracy: 0.4801 - val_loss: 2.0335 - val_accuracy: 0.2280 - val_sparse_top_k_categorical_accuracy: 0.7425
# Epoch 79/240
# 327/327 [==============================] - 198s 604ms/step - loss: 2.3354 - accuracy: 0.2335 - sparse_top_k_categorical_accuracy: 0.4762 - val_loss: 2.0325 - val_accuracy: 0.2311 - val_sparse_top_k_categorical_accuracy: 0.7433
# Epoch 80/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.3146 - accuracy: 0.2470 - sparse_top_k_categorical_accuracy: 0.4817 - val_loss: 2.0295 - val_accuracy: 0.2318 - val_sparse_top_k_categorical_accuracy: 0.7391
# Epoch 81/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.3157 - accuracy: 0.2486 - sparse_top_k_categorical_accuracy: 0.4771 - val_loss: 1.9792 - val_accuracy: 0.2770 - val_sparse_top_k_categorical_accuracy: 0.7613
# Epoch 82/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.3260 - accuracy: 0.2316 - sparse_top_k_categorical_accuracy: 0.4728 - val_loss: 2.0297 - val_accuracy: 0.2326 - val_sparse_top_k_categorical_accuracy: 0.7437
# Epoch 83/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.3187 - accuracy: 0.2411 - sparse_top_k_categorical_accuracy: 0.4756 - val_loss: 2.0462 - val_accuracy: 0.2131 - val_sparse_top_k_categorical_accuracy: 0.7418
# Epoch 84/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.3245 - accuracy: 0.2517 - sparse_top_k_categorical_accuracy: 0.4802 - val_loss: 2.1155 - val_accuracy: 0.1947 - val_sparse_top_k_categorical_accuracy: 0.7127
# Epoch 85/240
# 327/327 [==============================] - 197s 602ms/step - loss: 2.3100 - accuracy: 0.2464 - sparse_top_k_categorical_accuracy: 0.4770 - val_loss: 2.0183 - val_accuracy: 0.2311 - val_sparse_top_k_categorical_accuracy: 0.7460
# Epoch 86/240
# 327/327 [==============================] - 197s 603ms/step - loss: 2.3092 - accuracy: 0.2466 - sparse_top_k_categorical_accuracy: 0.4752 - val_loss: 1.9879 - val_accuracy: 0.2487 - val_sparse_top_k_categorical_accuracy: 0.7598
# Epoch 87/240
# 327/327 [==============================] - 195s 597ms/step - loss: 2.3090 - accuracy: 0.2478 - sparse_top_k_categorical_accuracy: 0.4789 - val_loss: 2.0068 - val_accuracy: 0.2357 - val_sparse_top_k_categorical_accuracy: 0.7525
# Epoch 88/240
# 327/327 [==============================] - 199s 608ms/step - loss: 2.2886 - accuracy: 0.2550 - sparse_top_k_categorical_accuracy: 0.4863 - val_loss: 1.9848 - val_accuracy: 0.2383 - val_sparse_top_k_categorical_accuracy: 0.7632
# Epoch 89/240
# 327/327 [==============================] - 195s 595ms/step - loss: 2.2657 - accuracy: 0.2470 - sparse_top_k_categorical_accuracy: 0.5010 - val_loss: 2.0007 - val_accuracy: 0.2188 - val_sparse_top_k_categorical_accuracy: 0.7659
# Epoch 90/240
# 240/327 [=====================>........] - ETA: 48s - loss: 2.2662 - accuracy: 0.2462 - sparse_top_k_categorical_accuracy: 0.5243

# %%
model_name = 'InceptionV3_40_200e_GSP1.0'

# %%
model.save_weights(f'../models/{model_name}_weights.h5')
model.save(f'../models/{model_name}_model.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

t5acc = history.history['sparse_top_k_categorical_accuracy']
t5val_acc = history.history['val_sparse_top_k_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

t5acc += history_fine.history['sparse_top_k_categorical_accuracy']
t5val_acc += history_fine.history['val_sparse_top_k_categorical_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10,8), sharex=True)

x_plot = np.arange(1, total_epochs+1)

ax[0].plot(x_plot, acc[:total_epochs], '+-', label='training')
ax[0].plot(x_plot, val_acc[:total_epochs], '+-', label='validation')
ax[0].plot(x_plot, t5acc[:total_epochs], '+-', label='top 5 training')
ax[0].plot(x_plot, t5val_acc[:total_epochs], '+-', label='top 5 validation')
ax[0].legend()
ax[0].set_ylabel('accuracy')
# ax[0].set_ylim(0.5, 1)
ax[0].grid(ls='--', c='C7')
ax[0].set_title('accuracy')
ax[0].axvline(initial_epochs, c='C7', ls='--')

ax[1].plot(x_plot, loss[:total_epochs], '+-', label='training')
ax[1].plot(x_plot, val_loss[:total_epochs], '+-', label='validation')
ax[1].legend()
ax[1].set_ylabel('cross entropy')
# ax[1].set_ylim(0, 1)
ax[1].grid(ls='--', c='C7')
ax[1].set_title('loss')
ax[1].set_xlabel('epoch')
ax[1].axvline(initial_epochs, c='C7', ls='--')

plt.show()

plt.savefig(f'../models/{model_name}_graph.svg')
plt.savefig(f'../models/{model_name}_graph.png', dpi=400)

# %%
graph_vals = pd.DataFrame({'acc':acc[:total_epochs],
                           'val_acc':val_acc[:total_epochs],
                           'loss':loss[:total_epochs],
                           'val_loss':val_loss[:total_epochs],
                           't5':t5acc[:total_epochs],
                           'val_t5':t5val_acc[:total_epochs]})

graph_vals.to_csv(f'../models/{model_name}_metrics.csv', index=False)

# %%
val_predictions = model.predict(val_ds, batch_size=BATCH_SIZE)

# %%
def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")r4t
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

# %%
plt.savefig('../models/VGG16_70e_1.0.svg')

# %%
model.save_weights('../models/VGG16_20_100e_1.0.h5')
model.save('../models/VGG16_20_100e_1.0.h5')

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.

    Args:
    cm (array, shape = [n, n]): a confusion matrix of integer classes
    class_names (array, shape = [n]): String names of the integer classes
    """
    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Normalize the confusion matrix.
    cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    color = "white" if cm[i, j] > threshold else "black"
    plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure

# %%
# Use the model to predict the values from the validation dataset.
test_pred_raw = model.predict(val_ds)
test_pred = np.argmax(test_pred_raw, axis=1)

# Calculate the confusion matrix.
cm = sklearn.metrics.confusion_matrix(test_labels, test_pred)
# Log the confusion matrix as an image summary.
figure = plot_confusion_matrix(cm, class_names=class_names)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10,8), sharex=True)

x_vals = np.arange(1, epochs+1)

ax[0].plot(x_vals, acc, '+-', label='training')
ax[0].plot(x_vals, val_acc, '+-', label='validation')
ax[0].legend()
ax[0].set_ylabel('accuracy')
ax[0].set_ylim(0, 1)
ax[0].grid(ls='--', c='C7')
ax[0].set_title('accuracy')

ax[1].plot(x_vals, loss, '+-', label='training')
ax[1].plot(x_vals, val_loss, '+-', label='validation')
ax[1].legend()
ax[1].set_ylabel('cross entropy')
ax[1].set_ylim(0, 3)
ax[1].grid(ls='--', c='C7')
ax[1].set_title('loss')
ax[1].set_xlabel('epoch')

plt.show()

# %%
model.save_weights('../models/.h5')
model.save('../models/.h5')

# %% [markdown]
# # Evaluation

# %%
import glob

pred_path = '../data/pred_16c_only1/'

pred_ds = tf.keras.preprocessing.image_dataset_from_directory(
    pred_path,
#     labels = [0]*len(glob.glob(f'{pred_path}*')),
    image_size=(img_height, img_width),
    batch_size=batch_size
    )

normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
predictions = model.predict(pred_ds)
print(predictions)

# %%
# Generate arg maxes for predictions
classes = np.argmax(predictions, axis = 1)
print(classes[0])
print(class_names[classes[0]])

# %%
temp = tf.keras.models.load_model('../models/convmod_1.0.h5')

# %%
temp.summary()

# %%
dot_img_file = '../models/convmod_1.0.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)
